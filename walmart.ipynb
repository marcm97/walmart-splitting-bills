# %%
import re
from bs4 import BeautifulSoup
import pandas as pd
from requests import get
import time
from random import randint
from IPython.core.display import clear_output
from warnings import warn

# %%
text ="""<body><div class="js-content" data-tb-dyn="true"><div aria-hidden="false" class="styles__viewPort___yGIQS" style=""><a class="styles__skipNavigation___2CLnx" href="#shoppingContent">Skip to Main Content</a><div class="styles__slidingPanel___10lQR"><div class="styles__mainContent___2u4us styles__noCart___BZKfZ" data-automation-id="wip-layout"><header class="styles__navbar___ADqJH" data-automation-id="global-header-standard" role="banner"><ul class="styles__appSwitcher___1EJSl"><li><a data-automation-id="homeLink" aria-label="Walmart Grocery - selected" class="GroceryLogo__logo___3RwM2 styles__groceryLogo___2Btzm" href="/grocery/"><span class="styles__rebrandingGroceryText___2gE10">Pickup &amp; delivery</span></a></li><li><a data-automation-id="shopLink" href="https://www.walmart.com/" aria-label="Walmart.com" class="WalmartLogo__logo___2Y_gi"><span class="WalmartLogo__rebrandingWalmartText___19J0O">Walmart.com</span></a></li></ul><div class=""></div><div class="styles__groceryHeader___2rWEB"><div><nav class="NavigationButton__navigationBtnContainer___zwngv"><button aria-expanded="false" aria-label="Menu" class="NavigationButton__button___AFDpS" data-automation-id="NavigationBtn" id="mobileNavigationBtn"><svg viewBox="0 0 20 20" aria-hidden="true" class="NavigationButton__hamburgerIcon___3sjZh" fill="#000000" height="20" version="1.1" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-18-menu"></use></svg></button><a data-automation-id="homeLink" aria-label="home" href="/grocery/"><svg viewBox="0 0 96 23" aria-hidden="true" class="NavigationButton__groceryRebrandingLogo___2b-3g responsive-effects__hide-below-m___2qbes" fill="#000000" height="20" version="1.1" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#walmart-logo"></use></svg><svg viewBox="0 0 14 16" aria-hidden="true" class="NavigationButton__rebrandingSparkIcon___3mrap responsive-effects__hide-above-m___3Xi4s" fill="#000000" height="20" version="1.1" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-18-spark"></use></svg></a></nav></div><div class="Search__rebrandingSearchBtnContainer___22n96"><form action="/search" class="Search__searchForm___2UBW_" data-automation-id="searchForm" id="searchForm"><input aria-haspopup="true" aria-label="Search For:" autocapitalize="off" autocomplete="off" autocorrect="off" class="Search__searchField___3eXaL" data-automation-id="searchField" maxlength="200" placeholder="Search my store" value=""><button aria-label="Clear Search" class="Search__clearSearchBtn___23GIj" data-automation-id="clearSearchBtn" type="button"><svg viewBox="0 0 14 14" aria-hidden="true" class="Search__clearSearchIcon___SPk6w" fill="#000000" height="20" version="1.1" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-18-remove"></use></svg></button><button aria-label="Perform Search" class="Search__searchBtn___15U4m" data-automation-id="searchBtn" type="submit"><svg viewBox="0 0 14 14" aria-hidden="true" fill="#000000" height="14px" version="1.1" width="14px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-18-search"></use></svg></button></form></div><a data-automation-id="accountLink" class="styles__accountOrSignInLink___3SF2A responsive-effects__hide-below-m___2qbes" href="/grocery/account"><svg viewBox="0 0 18 22" aria-hidden="true" fill="#000000" height="22px" version="1.1" width="18px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-24-account"></use></svg><span aria-label="Hi Marc, open my account" class="styles__title___1CiBK" data-automation-id="my-account-text">Hi, Marc</span></a><a data-automation-id="favoritesLink" class="styles__favoritesLink___iEKxr responsive-effects__hide-below-l___1_Xqw" href="/grocery/favorites"><svg viewBox="0 0 20 18" aria-hidden="true" fill="#000000" height="18px" version="1.1" width="20px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-heart-header"></use></svg><span class="styles__title___E41FD" data-automation-id="my-favorites-link">Favorites</span></a><button aria-label="0 items in the cart for total value of 0 dollars 00 cents" class="styles__container___2_rH3 styles__cartBadge___hVQ01" data-automation-id="CartBadge"><div aria-hidden="true" class="styles__iconBadge___3sg-O" data-automation-id="icon"><svg viewBox="0 0 20 20" aria-hidden="true" class="styles__iconCart___2GlPY" fill="#000000" height="20" version="1.1" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-24-bag"></use></svg><div class="styles__itemBadge___21UZM" data-automation-id="count">0</div></div><div aria-hidden="true" class="styles__priceContainer___3bJPW"><span class="styles__price___J4xwT">$0.00</span></div></button><div></div></div></header><section class="styles__scrollableBody___1dEFw" id="shoppingContent"><div class="order__unifiedAccountWrapper___1A61a"><div class="order__unifiedAccountHeader___10lM7"><a class="order__backButton___1lRVb" data-automation-id="unifiedAccount" href="/grocery/orders"><svg viewBox="0 0 10 16" aria-hidden="true" class="order__arrowIcon___gtjFA" fill="#000000" height="20" version="1.1" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-18-left-arrow"></use></svg></a><h2 aria-level="2" aria-live="polite">Order Details</h2></div><section class="OrderDetailsStatus__container___2J5n2" data-automation-id="OrderDetailsSummary"><div class="order__orderHeader___2Ttqf"><span>Order </span><b data-automation-id="orderId">7469207029594</b><div class="order__grandTotal___36s37"><div data-automation-id="grandTotal">$157.58</div></div></div><div class="OrderDetailsStatus__unifiedAccountRowWrapper___2rfW9"><div class="OrderDetailsStatus__trackerAndReturnsContainer___2nfJG"><div class="OrderDetailsStatus__unifiedAccountFirstSubcontainer___1oYj- OrderDetailsStatus__subContainer___kmSMW OrderDetailsStatus__unifiedAccountSubContainerOverrides___j4gq6 OrderDetailsStatus__trackerContainer___sp9fy OrderDetailsStatus__unifiedAccountOverrides___bzKh4"><div aria-label="Delivered. Your order was delivered on Jul 18. We look forward to your next order." class="OrderPreviewWithTracker__statusAndCTA___1vm2l OrderPreviewWithTracker__orderDetails___2mojT" data-automation-id="statusContainer-DELIVERY-DELIVERED"><div data-automation-id="statusBar"><div class="OrderPreviewWithTracker__relativeContainer___2Xsrf"><div class="OrderPreviewWithTracker__statusIconContainer___2z2Rp OrderPreviewWithTracker__oneThirdComplete___1dUx3 OrderPreviewWithTracker__twoThirdsComplete___1z7mA OrderPreviewWithTracker__threeThirdsComplete___1x1jD"><div class="OrderPreviewWithTracker__statusName___4-auz" data-automation-id="orderState">Delivered</div><div class="OrderPreviewWithTracker__ostCircle___3efqp"></div></div><div class="OrderPreviewWithTracker__statusContainer___30zBO" data-automation-id="progressBar"><div class="OrderPreviewWithTracker__section___jXa4u OrderPreviewWithTracker__complete___1GsQE"></div><div class="OrderPreviewWithTracker__section___jXa4u OrderPreviewWithTracker__complete___1GsQE"></div><div class="OrderPreviewWithTracker__section___jXa4u OrderPreviewWithTracker__complete___1GsQE"></div></div></div></div><div class="OrderPreviewWithTracker__unifiedAccountOrderStatusCopy___1XKuG" data-automation-id="orderStatusMessage">Your order was delivered on Jul 18. We look forward to your next order.</div><div class="OrderCallsToAction__orderCTAsContainer___AHC-T OrderCallsToAction__orderCTAsContainerAlignment___3xbgO OrderCallsToAction__addMarginBottom___3i1-N undefined"></div><div class="undefined"><div><div class="OrderPreviewWithTracker__itemIssueContainer___ZG30y"><div class="OrderPreviewWithTracker__itemIssueTitle___3kVst">Have an item issue?</div><div class="OrderPreviewWithTracker__itemIssueText___31oi5">If you have any item issues or aren’t satisfied with your substitutions, you can always start a return.</div><div class="OrderPreviewWithTracker__startAReturnBtnContainer___2sGCK"><button aria-label="Start a return" class="button-secondary-small OrderCallsToAction__commonLinks___1mKAr OrderCallsToAction__linkBtn___11GI6" data-automation-id="itemIssueLink" id="7469207029594">Start a return</button></div></div></div></div></div></div></div><div class="OrderDetailsStatus__unifiedAccountRemainingSubContainers___2QN3G"><div class="OrderDetailsStatus__subContainer___kmSMW OrderDetailsStatus__unifiedAccountSubContainerOverrides___j4gq6 OrderDetailsStatus__deliverySectionContainer___3jxna OrderDetailsStatus__unifiedAccountOverrides___bzKh4"><div class="OrderDetailsDeliveryInstructions__info___2WwdK"><div class="OrderDetailsDeliveryInstructions__flex___2qN-E"><svg data-automation-id="deliveryIcon" viewBox="0 0 18 18" aria-hidden="true" class="order__deliveryIcon___2kKSt" fill="#000000" height="20" version="1.1" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-18-delivery"></use></svg><div class="OrderDetailsDeliveryInstructions__addressContainer___2xO-t"><h5 aria-level="3" data-automation-id="fulfillmentTypeText">Delivery to</h5><div class="AddressPanel__container___1q2na" name=""><section><div><span class="AddressPanel__addressLine___3bRu7" data-automation-id="line1">125 E Kansas City St Apt 120</span><span class="AddressPanel__addressLine___3bRu7" data-automation-id="cityStatePostalCode">Rapid City, SD 57701</span></div></section></div></div></div></div><hr aria-hidden="true" class="OrderDetailsDeliveryInstructions__mobileDivider___3PpzL"><div class="OrderDetailsDeliveryInstructions__orderDateContainer___1DGRC"><div class="OrderDetailsDeliveryInstructions__splitFlex___3Fh01"><div class="OrderDetailsDeliveryInstructions__info___2WwdK OrderDetailsDeliveryInstructions__bold___3jJlH"><svg viewBox="0 0 18 18" aria-hidden="true" fill="#000000" height="20" version="1.1" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-18-orders-clock"></use></svg><span class="OrderDetailsDeliveryInstructions__headerText___EOx2-"><span data-automation-id="orderDate">Sat, Jul 18, 4pm–5pm</span></span></div></div></div><hr aria-hidden="true" class="OrderDetailsDeliveryInstructions__mobileDivider___3PpzL"><div class="OrderDetailsDeliveryInstructions__contactLessContainer___1mB9H"><svg viewBox="0 0 20 22" aria-hidden="true" class="OrderDetailsDeliveryInstructions__contactLessIcon___TJY7Q" fill="#000000" height="24" version="1.1" width="30" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#contact-less-delivery"></use></svg><div class="OrderDetailsDeliveryInstructions__contactLessTextContainer___32z9P"><span class="OrderDetailsDeliveryInstructions__contactlessText___2dmNp">You’ve selected to have this order left at your door <button class="button-link OrderDetailsDeliveryInstructions__learnMoreContactless___1CC-m">Learn more</button></span></div></div><hr aria-hidden="true" class="OrderDetailsDeliveryInstructions__mobileDivider___3PpzL"><hr aria-hidden="true" class="OrderDetailsDeliveryInstructions__divider___2lg-B"><hr aria-hidden="true" class="OrderDetailsDeliveryInstructions__mobileDivider___3PpzL"><div class="OrderDetailsDeliveryInstructions__info___2WwdK"><div class="OrderDetailsDeliveryInstructions__flex___2qN-E"><svg viewBox="0 0 18 18" aria-hidden="true" class="OrderDetailsDeliveryInstructions__mobileIcon___-Y3el" fill="#000000" height="24" version="1.1" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><use href="/grocery/js/sprite.4cc0a76e73678ac63a112638d2c0a0cd.svg#icn-18-mobile"></use></svg><div class="OrderDetailsDeliveryInstructions__flex___2qN-E OrderDetailsDeliveryInstructions__column___3dqZr"><h4 class="OrderDetailsDeliveryInstructions__mobileLabel___l_uE8" data-automation-id="label" id="aria-phoneType">Mobile</h4><div class="OrderDetailsDeliveryInstructions__mobileNumber___1g6Qv" data-automation-id="deliveryPhoneNumber">(605) 858-9635</div></div></div></div></div><div class="OrderDetailsStatus__subContainer___kmSMW OrderDetailsStatus__unifiedAccountSubContainerOverrides___j4gq6 OrderDetailsStatus__payments___22Ogr"><h5 aria-level="3" class="OrderDetailsDeliveryInstructions__paymentMethodHeader___1Y179" data-automation-id="paymentMethod">Payment method</h5><div class="OrderDetailsDeliveryInstructions__cardInfo___2LZ-i OrderDetailsDeliveryInstructions__flex___2qN-E" data-automation-id="order-details-payment-info"><img alt="DISCOVER" aria-hidden="true" class="styles__creditCardIcon___1hu04 OrderDetailsDeliveryInstructions__creditCard___2-1PO" src="//i5.walmartimages.com/dfw/63fd9f59-df66/c462295f-2c8a-4fc1-bf2c-7c0fe726a0d7/v1/c108609b068d5accc62a112b2d4a5490.png"><span class="OrderDetailsDeliveryInstructions__cardDescription___15HWm"><span>DISCOVER ending in </span><strong data-automation-id="last4Digits">6010</strong></span></div></div></div></div></section><section class="order__well___1z2J0" data-automation-id="OrderDetailsItemsContainer"><div class="order__splitFlex___3vsRd"><h3 class="order__itemDetails___3gONO" data-automation-id="ItemDetailsHeader">Item details</h3><button class="button-primary order__orderCTAButton___15NqV" data-automation-id="reorderAllBtn">Reorder all items</button></div><section class="OrderItemDetails__orderItemDetails___7Hksq" data
jpeg?odnHeight=150&amp;odnWidth=150&amp;odnBg=FFFFFF"></div><ol class="OrderItemTile__itemCol___19zNV"><li class="OrderItemTile__lineItem___2Gq06" data-automation-id="line-item"><div class="OrderItemTile__badgeContainer___de8h5"><div class="OrderItemTile__badgeAndSubstitution___3S0tn"></div><div class="OrderItemTile__badgeSpacer___IUNNg"></div></div><div class="OrderItemTile__rowContainer___3qR1_ OrderItemTile__orderDetailsRowContainer___gRS0o"><div class="OrderItemTile__rowName___8dQXg" data-automation-id="productName">Tropicana Pure Premium Original No Pulp 100% Orange Juice 89 fl. oz. Jug</div><div class="OrderItemTile__rowPriceContainer___2CY9L"><div class="OrderItemTile__rowQuantity___2pN1D" data-automation-id="basic-row-quantity"><span class="OrderItemTile__qty___3RzAu">Qty</span>1</div><div class="OrderItemTile__rowPrice___22B7_" data-automation-id="basic-row-totalPrice" name="line-item-total"><div class="" data-automation-id="totalValue">$5.18</div><div class="OrderItemTile__unitOfMeasure___1v3X5">($5.18/ea)</div></div></div></div></li></ol></div></li></div></li></ul></div></section><div aria-label="Order Summary" class="order__orderSummaryPrescriptive___35Prh" role="region"><ul class="OrderSummaryPrescriptive__orderSummaryPrescriptive___EaJLr" data-automation-id="prescriptive-oss"><li class="OrderSummaryPrescriptive__orderSummaryPrescriptiveItem___ojtSR OrderSummaryPrescriptive__amountItem___1sXwa" data-automation-id="prescriptive-oss-subTotal"><div class="OrderSummaryPrescriptive__itemLabel___P9vNQ">Sub total</div><div class="OrderSummaryPrescriptive__itemValue___-Tx9B">$148.12</div></li><li class="OrderSummaryPrescriptive__orderSummaryPrescriptiveItem___ojtSR OrderSummaryPrescriptive__amountItem___1sXwa" data-automation-id="prescriptive-oss-fulfillmentFee"><div class="OrderSummaryPrescriptive__itemLabel___P9vNQ">Delivery fee</div><div class="OrderSummaryPrescriptive__itemValue___-Tx9B">$0.00</div></li><li class="OrderSummaryPrescriptive__orderSummaryPrescriptiveItem___ojtSR OrderSummaryPrescriptive__amountItem___1sXwa" data-automation-id="prescriptive-oss-totalTax"><div class="OrderSummaryPrescriptive__itemLabel___P9vNQ">Total tax</div><div class="OrderSummaryPrescriptive__itemValue___-Tx9B">$9.46</div></li><li class="OrderSummaryPrescriptive__orderSummaryPrescriptiveItem___ojtSR OrderSummaryPrescriptive__amountItem___1sXwa OrderSummaryPrescriptive__type_TOTAL___3Gr6w" data-automation-id="prescriptive-oss-orderTotal"><div class="OrderSummaryPrescriptive__itemLabel___P9vNQ">Order total</div><div class="OrderSummaryPrescriptive__itemValue___-Tx9B">$157.58</div></li><li class="OrderSummaryPrescriptive__orderSummaryPrescriptiveItem___ojtSR OrderSummaryPrescriptive__amountItem___1sXwa" data-automation-id="prescriptive-oss-driverTip"><div class="OrderSummaryPrescriptive__itemLabel___P9vNQ">Driver tip</div><div class="OrderSummaryPrescriptive__itemValue___-Tx9B">$5.00</div></li></ul></div></section></div><div aria-hidden="true" class="env-info ResponsiveContainer">Electrode, Comp-830488823, DC-prod-cdc5, ENV-prod-alpha, PROF-PROD, VER-1.0.0-20200721_155204.d36c1fda0, SHA-d868fba3f668c54347c1c78cb0244423582a1583, CID-ca619d8c-2f7-1738c02e82e629</div><div><footer class="styles__container____hn6g responsive-effects__hide-for-print___3cq3x" data-automation-id="global-footer-standard"><div class="styles__linkContainer___1Uom4 responsive-effects__hide-below-m___2qbes"><div class="styles__column___3kBWv" data-automation-id="Customer-Service-column"><h4 class="styles__header___2uz0W">Customer Service</h4><ul class="styles__list___2s_Y1"><li class="styles__footerList___N9L2L"><a class="styles__linkColor___1lbaS" data-automation-id="Help-Link" href="/grocery/help">Help</a></li><li class="styles__footerList___N9L2L"><a class="styles__linkColor___1lbaS" data-automation-id="Refunds-Link" href="/grocery/help/article/how-do-i-get-a-refund/c2c45aba503b4532b2753df322792028">Refunds</a></li><li class="styles__footerList___N9L2L"><a href="https://corporate.walmart.com/
li class="styles__footerList___N9L2L"><a href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=og&amp;type=access" class="styles__linkColor___1lbaS" data-automation-id="Request-my-personal-information-Link">Request my personal information</a></li></ul></div></div><div class="styles__copyrightContainer___2nQQx" data-automation-id="copyright"><span data-automation-id="copyright" class="styles__copyRight___248bX">© 2020 Walmart. All Rights Reserved.</span><button data-automation-id="backToTopLink" class="styles__backToTop___3kEGr">Back to top</button></div></footer></div></section></div></div></div><div></div><div aria-atomic="true" aria-hidden="false" aria-live="polite" aria-relevant="additions text" class="AriaLive__hidden___3KH7C"></div><div class="toast__toastMessage___ntDt5" data-automation-id="toast-message" role="status"><div class="toast__messageWrapper___UVRND"><span class="toast__message___nRWkL"></span><span></span></div></div></div><script src="https://i5.wal.co/dfw/63fd9f59-cf44/9a8b3475-baed-4948-8d60-b6d52070221b/v1/core.bundle.cb5723d3e236c5cdd68e.js-2e0c05bd488fe08e35b8e198868bdd120a8d4621-br.js"></script><script src="//i5.walmartimages.com/dfw/63fd9f59-df66/c462295f-2c8a-4fc1-bf2c-7c0fe726a0d7/v1/discovery.bundle.0a1ec1508657437af102.js" id="bundleJs" defer="true"></script><script>if (window.webappStart) webappStart();</script><noscript>
    &lt;h4&gt;JavaScript is Disabled&lt;/h4&gt;
    &lt;p&gt;Sorry, this webpage requires JavaScript to function correctly.&lt;/p&gt;
    &lt;p&gt;Please enable JavaScript in your browser and reload the page.&lt;/p&gt;
  </noscript>
<script src="//i5.walmartimages.com/a14/cdn-doms-usgm.js"></script><script async="async" defer="defer" src="//i5.walmartimages.com/a14/cdn-perf.min.js"></script><script>window.SW_DOMAIN = "walmart.com"</script><script>(function(e){var t=e.document;BOOMR=e.BOOMR||{};BOOMR.plugins=BOOMR.plugins||{};var n={localStorageTestKey:"TorbitLSTest",pageTags:[],pageConversions:[],initHasRun:false};BOOMR.plugins.pageMeta={init:function(r){initHasRun=true;try{localStorage.setItem(n.localStorageTestKey,n.localStorageTestKey);localStorage.removeItem(n.localStorageTestKey);BOOMR.addVar("ls",1)}catch(i){BOOMR.addVar("ls",0)}if(e.location.protocol=="https:")BOOMR.addVar("prt",1);else BOOMR.addVar("prt",0);BOOMR.addVar("ref",t.referrer);if(e.performance&&e.performance.memory){for(m_name in e.performance.memory){if(e.performance.memory.hasOwnProperty(m_name)){BOOMR.addVar(m_name,e.performance.memory[m_name])}}}BOOMR.addVar("wH",e.innerHeight||t.body.clientHeight||t.documentElement.clientHeight);BOOMR.addVar("tags",n.pageTags.join("|"));return this},addTag:function(e){n.pageTags.push(e);if(!n.initHasRun){return}BOOMR.addVar("tags",n.pageTags.join("|"))},addConversion:function(e,t){var r=e;if(t&&(t>0||t.length>0))r=e+"="+t;n.pageConversions.push(r);BOOMR.addVar("conversion",n.pageConversions.join("|"))},is_complete:function(){return true}}})(window);(function(e){try{e._tbq=e._tbq||[];_tbq.push=function(e){if(e.length<1||!e[0])return;switch(e[0]){case"tag":if(e.length<2)return;BOOMR.plugins.pageMeta.addTag(e[1]);break;case"startTimer":if(e.length<2)return;BOOMR.plugins.customEvents.startTimer(e[1]);break;case"endTimer":if(e.length<2)return;BOOMR.plugins.customEvents.endTimer(e[1]);break}};for(i in _tbq){if(_tbq.hasOwnProperty(i)&&i!="push"){_tbq.push(_tbq[i]);delete _tbq[i]}}}catch(t){}})(window);</script><script type="text/javascript" id="" src="https://vt.myvisualiq.net/2/n4sFI2trsKIirkhjOnXj9g%3D%3D/vt-259.js"></script></body>"""

# %%
html_soup = BeautifulSoup(text, 'html')
items = html_soup.find_all(class_ = "OrderItemDetails__groupTableContainer___18ez5")

# %%
items[1].find_all("div",{"data-automation-id" :"details-table-header"})[0].text
# Out:
# 'Weight-adjusted'

# %%
walmart_items =[]
walmart_cost =[]
for order in items:

    if order.find_all("div",{"data-automation-id" :"details-table-header"})[0].text=="Unavailable":
        continue
    
    elif order.find_all("div",{"data-automation-id" :"details-table-header"})[0].text=="Substitutions":
        order_items = order.find_all(class_="OrderItemTile__rowName___8dQXg")[1::2]
        order_prices = order.find_all(class_="OrderItemTile__rowPrice___22B7_")[1::2]
        
    else:
        order_items = order.find_all(class_="OrderItemTile__rowName___8dQXg")
        order_prices = order.find_all(class_="OrderItemTile__rowPrice___22B7_")
        
    for item, price in zip(order_items,order_prices):
        walmart_items.append(item.text)
        walmart_cost.append(float(price.text.split("(")[0][1:]))
        
shipping = html_soup.find_all("li",{"data-automation-id" :"prescriptive-oss-fulfillmentFee"})[0].text.split("$")[-1]
tax = html_soup.find_all("li",{"data-automation-id" :"prescriptive-oss-totalTax"})[0].text.split("$")[-1]
tip =html_soup.find_all("li",{"data-automation-id" :"prescriptive-oss-driverTip"})[0].text.split("$")[-1]

for extra in ['shipping','tax','tip']:
    if extra!=None:
        walmart_items.append(str(extra))
        walmart_cost.append(float(eval(extra)))

# %%
walmart = pd.DataFrame(list(zip(walmart_items, walmart_cost)), 
               columns =['Items', 'Cost'])

# %%
order_date = html_soup.find_all("span",{"data-automation-id" :"orderDate"})[0].text

# %%
walmart.to_csv(str(order_date)+".csv")

# %%
walmart["Cost"].sum()
# Out:
# 162.58

# %%
walmart
# Out:
#                                                 Items   Cost
# 0                              Organic Bananas, Bunch   4.44
# 1   Frozen Raw Small Peeled Deveined Tailoff Shrim...   5.00
# 2          Marketside Bacon Caesar Salad Kit, 11.6 oz   3.63
# 3   Oroweat Country Buttermilk Bread, Made with Re...   3.18
# 4   Light & Fit Nonfat Gluten-Free Strawberry Chee...   3.17
# 5   Great Value Everyday Strong Paper Towels, Spli...   3.82
# 6   Cottonelle Ultra ComfortCare Soft, 6 Mega Roll...   6.48
# 7   Freshness Guaranteed Boneless Chicken Breasts ...  21.96
# 8   Great Value Caribbean Jerk Wing Seasoning Mix,...   0.98
# 9               Great Value Tropical Trail Mix, 26 oz   4.98
# 10  Thomas' Plain Soft & Chewy Pre-Sliced Bagels, ...   9.72
# 11           TAZO Zen Tea Bags Green Tea, 20 Tea Bags   2.98
# 12                     Great Value Basmati Rice, 5 lb   7.58
# 13  Hershey's, Special Dark Mildly Sweet Chocolate...   4.48
# ...
